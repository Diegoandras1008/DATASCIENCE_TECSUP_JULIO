# %%
import pandas as pd
df = pd.read_csv("C:/Users/LENOVO/Downloads/empleados.csv")
df = df.set_index("id_empleado")

# %%
col_seleccionadas = df[["nombre", "departamento", "salario"]]
print(col_seleccionadas)
# Out:
#                    nombre departamento  salario
# id_empleado
# 1001           Marta Ruiz     Finanzas  44300.0
# 1002           Elena Sanz         RRHH  22000.0
# 1003           Ana Prieto       Ventas  58200.0
# 1004          Laura Gomez    Marketing  24900.0
# 1005         Paula Torres         RRHH  54800.0
# ...                   ...          ...      ...
# 1086         Nuria Torres  Operaciones  29700.0
# 1087           Diego Sanz         RRHH  36200.0
# 1088         Lucia Prieto  Operaciones  28500.0
# 1089         Sergio Gomez         RRHH  51600.0
# 1090            Ana Gomez    Marketing  41400.0
#
# [90 rows x 3 columns]

# %%
filas_especificas = df.loc[[1003, 1007, 1015], ["nombre", "departamento", "salario"]]
print(filas_especificas)
# Out:
#                    nombre departamento  salario
# id_empleado
# 1003           Ana Prieto       Ventas  58200.0
# 1007         Javier Nieto           IT  44400.0
# 1015           Sofia Mora           IT  37100.0

# %%
primeras_filas_cols = df.iloc[0:10, 1:4]
print(primeras_filas_cols)
# Out:
#             departamento     ciudad  salario
# id_empleado
# 1001            Finanzas   Valencia  44300.0
# 1002                RRHH     Madrid  22000.0
# 1003              Ventas     Bilbao  58200.0
# 1004           Marketing    Sevilla  24900.0
# 1005                RRHH     Madrid  54800.0
# 1006            Finanzas   Valencia  49200.0
# 1007                  IT   Valencia  44400.0
# 1008         Operaciones  Barcelona  28600.0
# 1009         Operaciones     Madrid  39700.0
# 1010            Finanzas    Sevilla  32800.0

# %%
top_5_salario = df.sort_values(by="salario", ascending=False).head(5)
print(top_5_salario)
# Out:
#                    nombre departamento     ciudad  salario fecha_contratacion  \
# id_empleado
# 1032          Diego Gomez    Marketing     Madrid  59500.0         2023-07-14
# 1053         Laura Torres           IT  Barcelona  59400.0         2016-03-30
# 1003           Ana Prieto       Ventas     Bilbao  58200.0         2024-02-21
# 1046          Marta Ortiz     Finanzas     Madrid  57500.0         2018-07-03
# 1062         Diego Prieto         RRHH     Madrid  55600.0         2015-01-06
#
#              evaluacion
# id_empleado
# 1032                5.0
# 1053                1.0
# 1003                4.0
# 1046                5.0
# 1062                1.0

# %%
ordenado_dep_salario = df.sort_values(
    by=["departamento", "salario"], 
    ascending=[True, False]
)
print(ordenado_dep_salario)
# Out:
#                     nombre departamento     ciudad  salario  \
# id_empleado
# 1046           Marta Ortiz     Finanzas     Madrid  57500.0
# 1006            Lucia Mora     Finanzas   Valencia  49200.0
# 1001            Marta Ruiz     Finanzas   Valencia  44300.0
# 1055          Carlos Ortiz     Finanzas    Sevilla  43200.0
# 1039           Marta Gomez     Finanzas   Valencia  42900.0
# ...                    ...          ...        ...      ...
# 1054           Pedro Gomez       Ventas     Madrid  41400.0
# 1063          Sofia Torres       Ventas  Barcelona  40000.0
# 1024         Sergio Torres       Ventas     Madrid  25400.0
# 1020           Javier Sanz       Ventas     Madrid  22000.0
# 1048          Sofia Ferrer       Ventas  Barcelona  22000.0
#
#             fecha_contratacion  evaluacion
# id_empleado
# 1046                2018-07-03         5.0
# 1006                2022-03-25         3.0
# 1001                2024-06-12         2.0
# ...
